# %%
import os
import pandas as pd
import sqlite3

# %%
ls
# Out:
# SQLAlchemy Attempt.ipynb  pressure.csv              wind_direction.csv
# Untitled.ipynb            temperature.csv           wind_speed.csv
# city_attributes.csv       temperature_date.db
# humidity.csv              weather_description.csv

# %%
cty_att = pd.read_csv('city_attributes.csv')
humid = pd.read_csv

# %%
database = {}
for i in list(os.listdir()):
    if '.csv' in i:
        key = (i[:i.find('.csv')])
        database[key] = pd.read_csv(i)

# %%
conn = sqlite3.connect('weather.db')
for i in database.keys():
    database[i].to_sql(i, conn)
# Out:
# /Users/ryanpierson/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:2127: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %%
c = conn.cursor()

# %%
for i in c.execute('Select * from humidity limit 5'):
    print(i)
# Out:
# (0, '2012-10-01 12:00:00', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 25.0, None, None, None)
# (1, '2012-10-01 13:00:00', 76.0, 81.0, 88.0, 81.0, 88.0, 82.0, 22.0, 23.0, 50.0, 62.0, 93.0, 87.0, 93.0, 71.0, 67.0, 71.0, 71.0, 100.0, 76.0, 94.0, 76.0, 88.0, 87.0, 83.0, 93.0, 82.0, 71.0, 58.0, 93.0, 68.0, 50.0, 63.0, 22.0, 51.0, 51.0, 50.0)
# (2, '2012-10-01 14:00:00', 76.0, 80.0, 87.0, 80.0, 88.0, 81.0, 21.0, 23.0, 49.0, 62.0, 92.0, 86.0, 92.0, 70.0, 66.0, 71.0, 70.0, 99.0, 76.0, 94.0, 75.0, 87.0, 87.0, 82.0, 93.0, 81.0, 70.0, 57.0, 91.0, 68.0, 51.0, 62.0, 22.0, 51.0, 51.0, 50.0)
# (3, '2012-10-01 15:00:00', 76.0, 80.0, 86.0, 80.0, 88.0, 81.0, 21.0, 23.0, 49.0, 62.0, 92.0, 86.0, 90.0, 70.0, 66.0, 71.0, 70.0, 99.0, 76.0, 94.0, 75.0, 87.0, 87.0, 82.0, 93.0, 79.0, 70.0, 57.0, 87.0, 68.0, 51.0, 62.0, 22.0, 51.0, 51.0, 50.0)
# ...

# %%
query = 'Select * from humidity limit 5'

pd.read_sql(query, conn)
# Out:
#    index             datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0      0  2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1      1  2012-10-01 13:00:00       76.0      81.0           88.0     81.0
# 2      2  2012-10-01 14:00:00       76.0      80.0           87.0     80.0
# 3      3  2012-10-01 15:00:00       76.0      80.0           86.0     80.0
# 4      4  2012-10-01 16:00:00       77.0      80.0           85.0     79.0
#
#    Los Angeles  San Diego  Las Vegas  Phoenix    ...      Philadelphia  \
# 0          NaN        NaN        NaN      NaN    ...               NaN
# 1         88.0       82.0       22.0     23.0    ...              71.0
# 2         88.0       81.0       21.0     23.0    ...              70.0
# 3         88.0       81.0       21.0     23.0    ...              70.0
# 4         88.0       81.0       21.0     23.0    ...              69.0
#
#    New York  Montreal  Boston  Beersheba  Tel Aviv District  Eilat  Haifa  \
# ...

# %%
query = "SELECT name FROM weather.db WHERE type='table'"

pd.read_sql(query, conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1399             else:
# -> 1400                 cur.execute(*args)
#    1401             return cur
#
# OperationalError: no such table: weather.db
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-22-cca9363007be> in <module>()
#       1 query = "SELECT name FROM weather.db WHERE type='table'"
#       2
# ----> 3 pd.read_sql(query, conn)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     379             sql, index_col=index_col, params=params,
# ...

# %%
conn.tab
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-7dcf7f37add3> in <module>()
# ----> 1 conn.tab
#
# AttributeError: 'sqlite3.Connection' object has no attribute 'tab'

# %%
query = "select sql from sqlite_master where type = 'table'"

pd.read_sql(query, conn)
# Out:
#                                                  sql
# 0  CREATE TABLE "weather_description" (\n"index" ...
# 1  CREATE TABLE "humidity" (\n"index" INTEGER,\n ...
# 2  CREATE TABLE "wind_direction" (\n"index" INTEG...
# 3  CREATE TABLE "temperature" (\n"index" INTEGER,...
# 4  CREATE TABLE "pressure" (\n"index" INTEGER,\n ...
# 5  CREATE TABLE "city_attributes" (\n"index" INTE...
# 6  CREATE TABLE "wind_speed" (\n"index" INTEGER,\...

# %%
query = "select * from temperature limit 5"

pd.read_sql(query, conn)
# Out:
#    index             datetime   Vancouver    Portland  San Francisco  \
# 0      0  2012-10-01 12:00:00         NaN         NaN            NaN
# 1      1  2012-10-01 13:00:00  284.630000  282.080000     289.480000
# 2      2  2012-10-01 14:00:00  284.629041  282.083252     289.474993
# 3      3  2012-10-01 15:00:00  284.626998  282.091866     289.460618
# 4      4  2012-10-01 16:00:00  284.624955  282.100481     289.446243
#
#       Seattle  Los Angeles   San Diego   Las Vegas     Phoenix    ...      \
# 0         NaN          NaN         NaN         NaN         NaN    ...
# 1  281.800000   291.870000  291.530000  293.410000  296.600000    ...
# 2  281.797217   291.868186  291.533501  293.403141  296.608509    ...
# 3  281.789833   291.862844  291.543355  293.392177  296.631487    ...
# 4  281.782449   291.857503  291.553209  293.381213  296.654466    ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# ...
